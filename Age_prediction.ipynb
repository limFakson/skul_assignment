# %%
# Import necessary libraries
from sklearn.metrics import f1_score, accuracy_score, recall_score, precision_score, mean_squared_error, classification_report
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier # example model
import pandas as pd
import numpy as np

# %%
# save train csv file in train data
train_data = pd.read_csv(r"C:\Users\USER\Desktop\Fakson_web\Programs\lessons\Python\Jupyter\dataset\AgeTrain.csv")
test_data = pd.read_csv(r'C:\Users\USER\Desktop\Fakson_web\Programs\lessons\Python\Jupyter\dataset\AgeTest.csv')
train_data.head()
# Out:
#    Gender  Height (cm)  Weight (kg) Blood Pressure (s/d)  \
# 0    Male   171.148359    86.185197              151/109
# 1    Male   172.946206    79.641937              134/112
# 2  Female   155.945488    49.167058              160/101
# 3  Female   169.078298    56.017921               133/94
# 4  Female   163.758355    73.966304              170/106
#
#    Cholesterol Level (mg/dL)        BMI  Blood Glucose Level (mg/dL)  \
# 0                 259.465814  29.423017                   157.652848
# 1                 263.630292  26.626847                   118.507805
# 2                 207.846206  20.217553                   143.587550
# 3                 253.283779  19.595270                   137.448581
# 4                 236.119899  27.582078                   145.328695
#
#    Bone Density (g/cm²)  Vision Sharpness  Hearing Ability (dB)  ...  \
# 0              0.132868          0.200000             58.786198  ...
# 1              0.629534          0.267312             54.635270  ...
# 2              0.473487          0.248667             54.564632  ...
# 3              1.184315          0.513818             79.722963  ...
# 4              0.434562          0.306864             52.479469  ...
#
#   Family History Cognitive Function Mental Health Status Sleep Patterns  \
# 0            NaN          44.059172                 Good       Insomnia
# 1  Heart Disease          45.312298                 Good         Normal
# 2   Hypertension          56.246991                 Poor       Insomnia
# 3   Hypertension          55.196092                 Poor       Insomnia
# 4            NaN          53.023379                 Good         Normal
#
#   Stress Levels Pollution Exposure Sun Exposure  Education Level Income Level  \
# 0      2.797064           5.142344     7.108975              NaN       Medium
# 1      9.339930           7.272720     3.918489    Undergraduate       Medium
# 2      9.234637           8.500386     5.393408              NaN       Medium
# 3      4.693446           7.555511     2.745578              NaN          Low
# 4      4.038537           9.429097     3.878435    Undergraduate         High
#
#   Age (years)
# 0          89
# 1          77
# 2          70
# 3          52
# 4          79
#
# [5 rows x 26 columns]

# %%
# import LabelEncoder from sklearn
from sklearn.preprocessing import LabelEncoder

# covert the continuous value into int
# Assuming 'Blood Pressure' is the column containing '124/101' format
train_data[['BP_Systolic', 'BP_Diastolic']] = train_data['Blood Pressure (s/d)'].str.split('/', expand=True).astype(float)
test_data[['BP_Systolic', 'BP_Diastolic']] = test_data['Blood Pressure (s/d)'].str.split('/', expand=True).astype(float)

# Drop the original column after splitting (optional)
drop_column = ['Blood Pressure (s/d)','Alcohol Consumption','Family History','Education Level','Chronic Diseases','Medication Use','Physical Activity Level']
filt_data = train_data.drop(drop_column, axis=1)
test_filt_data = test_data.drop(drop_column, axis=1)

# Assuming 'x_train' contains a column with string values
label_encoder = LabelEncoder()

# Apply the label encoder to the specific column (e.g., 'category_column')
categorical_columns = ['Smoking Status','Diet','Mental Health Status','Sleep Patterns','Income Level']
label_encoder = LabelEncoder()
for col in categorical_columns:
    filt_data[col] = label_encoder.fit_transform(filt_data[col])
    test_filt_data[col] = label_encoder.transform(test_filt_data[col])

print(train_data.shape)
x = filt_data.drop('Gender',axis=1)
# Out:
# (3000, 28)

# %%
# Define the target (y) and features (X)
y = filt_data['Gender']  # Target

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=1000)

# For test data, we do not have the 'Age (years)' column
test_model = test_data.copy()

# Check the shapes of x_train and y_train
print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
y_train.head()
# Out:
# x_train shape: (2700, 20)
# y_train shape: (2700,)
# 2445      Male
# 934       Male
# 531     Female
# 2627      Male
# 441       Male
# Name: Gender, dtype: object

# %%
rl = RandomForestClassifier()
dc = DecisionTreeClassifier()
dc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
age_pred = dc.predict(x_train)
print(age_pred.shape)
# Out:
# (2700,)

# %%
model_accuracy = accuracy_score(age_pred, y_train)
print(f'Train model_accuracy: {model_accuracy}')
test_pred = dc.predict(x_test)
test_accuracy = accuracy_score(test_pred, y_test)
print(f'Train model_accuracy: {test_accuracy}')
# Out:
# Train model_accuracy: 1.0
# Train model_accuracy: 0.8266666666666667

# %%
# 'macro' calculates recall for each class and then averages them.
recall = recall_score(y_test, test_pred, average='macro')

# Step 7: Print the recall
print(f"Recall of the model: {recall:.2f}")
# Out:
# Recall of the model: 0.83

# %%
# Calculate the F1 score
f1 = f1_score(y_test, test_pred, average='macro')  # Use 'weighted' for multiclass, 'binary' for binary classification

# Print the F1 score
print(f'F1 Score: {f1}')
# Out:
# F1 Score: 0.8265433196940046

# %%
# Step 6: Calculate precision
# For multiclass classification, specify the `average` parameter.
# 'macro' calculates precision for each class and then averages them.
precision = precision_score(y_test, test_pred, average='macro')

# Step 7: Print the precision
print(f"Precision of the model: {precision:.2f}")
# Out:
# Precision of the model: 0.83

# %%
report = classification_report(y_test, test_pred)
print(f'report{report}')
# Out:
# report              precision    recall  f1-score   support
#
#       Female       0.79      0.86      0.82       140
#         Male       0.86      0.80      0.83       160
#
#     accuracy                           0.83       300
#    macro avg       0.83      0.83      0.83       300
# weighted avg       0.83      0.83      0.83       300

# %%
predictions_df = pd.DataFrame({'Predicted Age': test_pred, 'data_test':y_test, 'report':report})

# Save to CSV
predictions_df.to_csv(r'C:\Users\USER\Desktop\Fakson_web\Programs\lessons\Python\Jupyter\dataset\predicted_ages.csv', index=False)
predictions_df
# Out:
#      Predicted Age data_test  \
# 1013        Female    Female
# 2827        Female      Male
# 2369        Female    Female
# 846           Male      Male
# 1699        Female    Female
# ...            ...       ...
# 2455          Male      Male
# 2152          Male      Male
# 236           Male      Male
# 785         Female    Female
# 2306        Female    Female
#
#                                                  report
# 1013                precision    recall  f1-score   ...
# 2827                precision    recall  f1-score   ...
# 2369                precision    recall  f1-score   ...
# 846                 precision    recall  f1-score   ...
# 1699                precision    recall  f1-score   ...
# ...                                                 ...
# 2455                precision    recall  f1-score   ...
# 2152                precision    recall  f1-score   ...
# 236                 precision    recall  f1-score   ...
# 785                 precision    recall  f1-score   ...
# 2306                precision    recall  f1-score   ...
#
# [300 rows x 3 columns]
