# %%
# Import necessary libraries
from sklearn.metrics import f1_score, accuracy_score, recall_score, precision_score, mean_squared_error, classification_report
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier # example model
import pandas as pd
import numpy as np

# %%
# save train csv file in train data
train_data = pd.read_csv(r"C:\Users\USER\Desktop\Fakson_web\Programs\lessons\Python\Jupyter\dataset\vicsdata\Student Mental health.csv")
train_data.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# 1                      No                  Yes                        No
# 2                     Yes                  Yes                       Yes
# 3                     Yes                   No                        No
# 4                      No                   No                        No
#
#   Did you seek any specialist for a treatment?
# 0                                           No
# 1                                           No
# 2                                           No
# 3                                           No
# 4                                           No

# %%
# import LabelEncoder from sklearn
from sklearn.preprocessing import LabelEncoder

# Drop the original column after splitting (optional)
drop_column = ['Timestamp', 'What is your CGPA?']
filt_data = train_data.drop(drop_column, axis=1)

# Assuming 'x_train' contains a column with string values
label_encoder = LabelEncoder()

# Apply the label encoder to the specific column (e.g., 'category_column')
categorical_columns = ['Choose your gender','What is your course?','Your current year of Study','Do you have Depression?','Do you have Anxiety?','Do you have Panic attack?','Did you seek any specialist for a treatment?']
label_encoder = LabelEncoder()
for col in categorical_columns:
    filt_data[col] = label_encoder.fit_transform(filt_data[col])

print(train_data.shape)
x = filt_data.drop('Marital status',axis=1)
x.head()
# Out:
# (101, 11)
#    Choose your gender   Age  What is your course?  Your current year of Study  \
# 0                   0  18.0                    17                           3
# 1                   1  21.0                    25                           4
# 2                   1  19.0                     4                           0
# 3                   0  22.0                    33                           5
# 4                   1  23.0                    37                           6
#
#    Do you have Depression?  Do you have Anxiety?  Do you have Panic attack?  \
# 0                        1                     0                          1
# 1                        0                     1                          0
# 2                        1                     1                          1
# 3                        1                     0                          0
# 4                        0                     0                          0
#
#    Did you seek any specialist for a treatment?
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0

# %%
# Define the target (y) and features (X)
y = filt_data['Marital status']  # Target

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=1000)

# Check the shapes of x_train and y_train
print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
y_train.head()
# Out:
# x_train shape: (90, 8)
# y_train shape: (90,)
# 48     No
# 65     No
# 91     No
# 99     No
# 39    Yes
# Name: Marital status, dtype: object

# %%
rl = RandomForestClassifier()
dc = DecisionTreeClassifier()
dc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
age_pred = dc.predict(x_train)
print(age_pred.shape)
# Out:
# (90,)

# %%
model_accuracy = accuracy_score(age_pred, y_train)
print(f'Train model_accuracy: {model_accuracy}')
test_pred = dc.predict(x_test)
test_accuracy = accuracy_score(test_pred, y_test)
print(f'Train model_accuracy: {test_accuracy}')
# Out:
# Train model_accuracy: 1.0
# Train model_accuracy: 0.7272727272727273

# %%
# 'macro' calculates recall for each class and then averages them.
recall = recall_score(y_test, test_pred, average='macro')

# Step 7: Print the recall
print(f"Recall of the model: {recall:.2f}")
# Out:
# Recall of the model: 0.60

# %%
# Calculate the F1 score
f1 = f1_score(y_test, test_pred, average='macro')  # Use 'weighted' for multiclass, 'binary' for binary classification

# Print the F1 score
print(f'F1 Score: {f1}')
# Out:
# F1 Score: 0.611764705882353

# %%
# Step 6: Calculate precision
# For multiclass classification, specify the `average` parameter.
# 'macro' calculates precision for each class and then averages them.
precision = precision_score(y_test, test_pred, average='macro')

# Step 7: Print the precision
print(f"Precision of the model: {precision:.2f}")
# Out:
# Precision of the model: 0.64

# %%
report = classification_report(y_test, test_pred)
print(f'report{report}')
# Out:
# report              precision    recall  f1-score   support
#
#           No       0.78      0.88      0.82         8
#          Yes       0.50      0.33      0.40         3
#
#     accuracy                           0.73        11
#    macro avg       0.64      0.60      0.61        11
# weighted avg       0.70      0.73      0.71        11

# %%
predictions_df = pd.DataFrame({'Predicted Age': test_pred, 'data_test':y_test, 'report':report})

# Save to CSV
predictions_df.to_csv(r'C:\Users\USER\Desktop\Fakson_web\Programs\lessons\Python\Jupyter\dataset\predicted_mental_health.csv', index=False)
predictions_df
# Out:
#    Predicted Age data_test                                             report
# 37            No        No                precision    recall  f1-score   ...
# 97           Yes        No                precision    recall  f1-score   ...
# 56            No        No                precision    recall  f1-score   ...
# 55            No        No                precision    recall  f1-score   ...
# 33           Yes       Yes                precision    recall  f1-score   ...
# 84            No        No                precision    recall  f1-score   ...
# 3             No       Yes                precision    recall  f1-score   ...
# 4             No        No                precision    recall  f1-score   ...
# 72            No       Yes                precision    recall  f1-score   ...
# 59            No        No                precision    recall  f1-score   ...
# 66            No        No                precision    recall  f1-score   ...
